# %%
from scrapper_juan_salas import ejecutar_extraccion

NOMBRE_GRUPO = "G5_Turismo_y_Hosteleria"
CATEGORIA_ACTUAL = "Travel"

try:
    client = MongoClient('database', 27017)
    db = client['proyecto_bigdata']
    coleccion = db['datos_libros']
    print("CONEXION EXITOSA: Listo para insertar datos de", CATEGORIA_ACTUAL)
except Exception as e:
    print("ERROR DE CONEXION:", e)

lista_libros = [
    {"titulo": "It's Only Himalaya", "precio": "45.17"},
    {"titulo": "Full Moon over Noahs Ark", "precio": "49.43"}
]

for libro in lista_libros:
    try:
        registro = {
            "item": libro["titulo"],
            "valor": float(libro["precio"].replace(' ', '').replace(',', '').strip()),
            "categoria": CATEGORIA_ACTUAL,
            "grupo": NOMBRE_GRUPO,
            "fecha_captura": time.strftime("%Y-%m-%d %H:%M:%S")
        }
        coleccion.insert_one(registro)
    except Exception as e:
        print("Error procesando libro:", e)

print("PROCESO FINALIZADO: Datos enviados a MongoDB.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from scrapper_juan_salas import ejecutar_extraccion
#       3 datos = ejecutar_extraccion(50)
#       5 print(datos[:5])
#
# ModuleNotFoundError: No module named 'scrapper_juan_salas'
