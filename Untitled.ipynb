# %%
from pymongo import MongoClient
import certifi

URI = "mongodb+srv://lucascheuque_db_user:27032005@cluster0.tjvu2a3.mongodb.net/?retryWrites=true&w=majority"
client = MongoClient(URI, tlsCAFile=certifi.where())
db = client['proyecto_bigdata']
coleccion = db['alojamientos']

print(f"Total general: {coleccion.count_documents({})}")

for plat in coleccion.distinct('plataforma'):
    count = coleccion.count_documents({'plataforma': plat})
    print(f"  {plat}: {count}")
# Out:
# Total general: 4754
#   Airbnb.cl: 826
#   Booking.com: 1050
#   Despegar.cl: 313
#   Google Hotels: 57
#   HotelsCombined: 607
#   Kayak.cl: 705
#   Rescate_Emergencia: 600
#   Trip.com: 83

# %%
# Unificar HotelsCombined
coleccion.update_many(
    {'plataforma': 'HotelsCombined.com'},
    {'$set': {'plataforma': 'HotelsCombined'}}
)
print("[OK] HotelsCombined.com -> HotelsCombined")

# Unificar Airbnb
coleccion.update_many(
    {'plataforma': 'airbnb.cl'},
    {'$set': {'plataforma': 'Airbnb.cl'}}
)
print("[OK] airbnb.cl -> Airbnb.cl")
# Out:
# [OK] HotelsCombined.com -> HotelsCombined
# [OK] airbnb.cl -> Airbnb.cl

# %%
from pymongo import MongoClient
import certifi

URI = "mongodb+srv://lucascheuque_db_user:27032005@cluster0.tjvu2a3.mongodb.net/?retryWrites=true&w=majority"
client = MongoClient(URI, tlsCAFile=certifi.where())
db = client['proyecto_bigdata']
coleccion = db['alojamientos']

# Unificar todas las variaciones de Trip
coleccion.update_many(
    {'plataforma': 'TripAdvisor.com'},
    {'$set': {'plataforma': 'Trip.com'}}
)
print("[OK] TripAdvisor.com -> Trip.com")

coleccion.update_many(
    {'plataforma': 'Trip Advisor'},
    {'$set': {'plataforma': 'Trip.com'}}
)
print("[OK] Trip Advisor -> Trip.com")

coleccion.update_many(
    {'plataforma': 'Tripadvisor'},
    {'$set': {'plataforma': 'Trip.com'}}
)
print("[OK] Tripadvisor -> Trip.com")
# Out:
# [OK] TripAdvisor.com -> Trip.com
# [OK] Trip Advisor -> Trip.com
# [OK] Tripadvisor -> Trip.com
