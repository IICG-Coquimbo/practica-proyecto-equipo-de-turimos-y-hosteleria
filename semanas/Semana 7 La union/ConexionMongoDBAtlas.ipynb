# %%
from pymongo import MongoClient
import certifi

uri = "mongodb+srv://lucascheuque_db_user:27032005@cluster0.tjvu2a3.mongodb.net/?retryWrites=true&w=majority"

client = MongoClient(
    uri,
    tlsCAFile=certifi.where(),
    serverSelectionTimeoutMS=5000
)

try:
    print(client.server_info())
    print(" Conexión exitosa")
except Exception as e:
    print(" Error:", e)
# Out:
# {'version': '8.0.21', 'gitVersion': 'e67138ffda9f90b59531128bc43678bb5ad105ed', 'modules': ['enterprise'], 'allocator': 'tcmalloc-google', 'javascriptEngine': 'mozjs', 'sysInfo': 'deprecated', 'versionArray': [8, 0, 21, 0], 'bits': 64, 'debug': False, 'maxBsonObjectSize': 16777216, 'storageEngines': ['devnull', 'inMemory', 'queryable_wt', 'wiredTiger'], 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1776893942, 12), 'signature': {'hash': b'\xaf\xf8\x1f\x9cD`\xe69\x9dz\xcb\xaa^\xfft5\xdbu\xe1J', 'keyId': 7574135394401255427}}, 'operationTime': Timestamp(1776893942, 12)}
#  Conexión exitosa

# %%
db = client["prueba"]
coleccion = db["personas"]

coleccion.insert_one({"nombre": "Jesús", "edad": 60})
# Out:
# InsertOneResult(ObjectId('69e91d6d020ab64ddc916665'), acknowledged=True)

# %%
from pymongo import MongoClient
import certifi

uri = uri = "mongodb+srv://bastianbravo01_db_user:Bastian.1699@cluster0.t4bq4v7.mongodb.net/?appName=Cluster0"

client = MongoClient(
    uri,
    tlsCAFile=certifi.where(),
    serverSelectionTimeoutMS=5000
)

try:
    print(client.server_info())
    print(" Conexión exitosa")
except Exception as e:
    print(" Error:", e)
# Out:
# {'version': '8.0.21', 'gitVersion': 'e67138ffda9f90b59531128bc43678bb5ad105ed', 'modules': ['enterprise'], 'allocator': 'tcmalloc-google', 'javascriptEngine': 'mozjs', 'sysInfo': 'deprecated', 'versionArray': [8, 0, 21, 0], 'bits': 64, 'debug': False, 'maxBsonObjectSize': 16777216, 'storageEngines': ['devnull', 'inMemory', 'queryable_wt', 'wiredTiger'], 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1776884710, 3), 'signature': {'hash': b'{\xa5\xd9s\x0b\xf3\x08\xb4\x08\xd1]H\x0e\x0f\xd7}\xde\xb9\x9f\xe9', 'keyId': 7571908492512985092}}, 'operationTime': Timestamp(1776884710, 3)}
#  Conexión exitosa
