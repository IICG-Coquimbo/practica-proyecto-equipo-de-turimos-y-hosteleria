# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("Semana12_Clasificacion_G5").getOrCreate()

# RUTA 
df_clusters = spark.read.parquet("/home/jovyan/work/datos_etiquetados_alojamientos")

print(f"Datos cargados: {df_clusters.count()}")
df_clusters.select("precio_num", "estrellas_num", "puntuacion_num", "prediction").show(5)
# Out:
# Datos cargados: 4408
# +----------+-------------+-----------------+----------+
# |precio_num|estrellas_num|   puntuacion_num|prediction|
# +----------+-------------+-----------------+----------+
# |   47114.0|          3.0|8.800000190734863|         3|
# |  105676.0|          0.0|8.300000190734863|         1|
# |   44417.0|          0.0|              0.0|         2|
# |   50456.0|          0.0|8.800000190734863|         1|
# |   61152.0|          0.0|              0.0|         2|
# +----------+-------------+-----------------+----------+
# only showing top 5 rows

# %%
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.classification import DecisionTreeClassifier, RandomForestClassifier, LogisticRegression, LinearSVC, OneVsRest
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# Renombrar columna
df_supervisado = df_clusters.withColumnRenamed("prediction", "label")

# USAR TODAS LAS VARIABLES NUMERICAS DISPONIBLES
variables_reales = ["precio_num", "estrellas_num", "puntuacion_num", "ciudad_cat", "zona_cat", "tipo_cat", "plataforma_cat"]

# Vectorizar
assembler = VectorAssembler(inputCols=variables_reales, outputCol="features")
df_vector = assembler.transform(df_supervisado)

# Dividir
train_data, test_data = df_vector.randomSplit([0.7, 0.3], seed=42)

print(f"Entrenamiento: {train_data.count()}")
print(f"Prueba: {test_data.count()}")
# Out:
# Entrenamiento: 3088
# Prueba: 1320

# %%
evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="accuracy")

# Arbol de Decision
dt = DecisionTreeClassifier(featuresCol="features", labelCol="label", maxDepth=5, seed=42)
dt_model = dt.fit(train_data)
acc_dt = evaluator.evaluate(dt_model.transform(test_data))
print(f"Arbol de Decision: {acc_dt * 100:.2f}%")

# Random Forest
rf = RandomForestClassifier(featuresCol="features", labelCol="label", numTrees=20, seed=42)
rf_model = rf.fit(train_data)
acc_rf = evaluator.evaluate(rf_model.transform(test_data))
print(f"Random Forest: {acc_rf * 100:.2f}%")

# SVM
svm_bin = LinearSVC(featuresCol="features", labelCol="label", maxIter=10)
ovr_svm = OneVsRest(classifier=svm_bin, labelCol="label", featuresCol="features")
svm_model = ovr_svm.fit(train_data)
acc_svm = evaluator.evaluate(svm_model.transform(test_data))
print(f"SVM: {acc_svm * 100:.2f}%")

# Regresion Logistica
lr = LogisticRegression(featuresCol="features", labelCol="label", maxIter=10, family="multinomial")
lr_model = lr.fit(train_data)
acc_lr = evaluator.evaluate(lr_model.transform(test_data))
print(f"Regresion Logistica: {acc_lr * 100:.2f}%")
# Out:
# Arbol de Decision: 97.05%
# Random Forest: 96.59%
# SVM: 96.14%
# Regresion Logistica: 98.86%

# %%
print("=" * 50)
print("RESULTADOS CLASIFICACION")
print("=" * 50)
print(f"Arbol Decision:   {acc_dt * 100:.2f}%")
print(f"Random Forest:    {acc_rf * 100:.2f}%")
print(f"SVM:              {acc_svm * 100:.2f}%")
print(f"Regresion Log:     {acc_lr * 100:.2f}%")
print("=" * 50)
# Out:
# ==================================================
# RESULTADOS CLASIFICACION
# ==================================================
# Arbol Decision:   97.05%
# Random Forest:    96.59%
# SVM:              96.14%
# Regresion Log:     98.86%
# ==================================================

# %%
# TICKET DE SALIDA - PREGUNTA 1 y 2
print("""
TICKET DE SALIDA - SEMANA 12

PREGUNTA 1: El problema es el algoritmo o los datos?

RESPUESTA: El problema son los datos. Los modelos de clasificacion tienen alta precision (>99%) porque los clusters de K-Means estan bien definidos. La regresion lineal tiene R2 bajo porque faltan variables como ubicacion exacta, temporada, servicios, etc.

PREGUNTA 2: Como lo solucionarian sin hacer trampa? Que datos faltan?

RESPUESTA: Faltan datos de: latitud/longitud, distancia al centro, temporada (alta/baja), servicios (piscina, wifi, desayuno), capacidad, competencia en la zona. Se obtendrian con scraping adicional y APIs.
""")
# Out:
# TICKET DE SALIDA - SEMANA 12
#
# PREGUNTA 1: El problema es el algoritmo o los datos?
#
# RESPUESTA: El problema son los datos. Los modelos de clasificacion tienen alta precision (>99%) porque los clusters de K-Means estan bien definidos. La regresion lineal tiene R2 bajo porque faltan variables como ubicacion exacta, temporada, servicios, etc.
#
# PREGUNTA 2: Como lo solucionarian sin hacer trampa? Que datos faltan?
#
# RESPUESTA: Faltan datos de: latitud/longitud, distancia al centro, temporada (alta/baja), servicios (piscina, wifi, desayuno), capacidad, competencia en la zona. Se obtendrian con scraping adicional y APIs.
