# %% [markdown]
# # Algoritmos supervisados o semi-supervisados: Usando los datos de K-Means

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Clasificacion_Alojamientos_Matias") \
    .getOrCreate()

ruta_datos = "/home/jovyan/work/datos_etiquetados_alojamientos"

df_clusters = spark.read.parquet(ruta_datos)

df_supervisado = df_clusters.withColumnRenamed(
    "prediction",
    "label"
)

print("Total registros:", df_supervisado.count())

df_supervisado.groupBy("label").count().show()
# Out:
# Total registros: 4408
# +-----+-----+
# |label|count|
# +-----+-----+
# |    1|  494|
# |    3|  917|
# |    4|  624|
# |    2| 1120|
# |    0| 1253|
# +-----+-----+

# %% [markdown]
# ## Árbol de Decisión

# %%
from pyspark.ml.feature import VectorAssembler, StandardScaler

train_data, test_data = df_supervisado.randomSplit(
    [0.7, 0.3],
    seed=42
)

feature_cols = [
    "precio_num",
    "puntuacion_num",
    "estrellas_num",
    "ciudad_cat",
    "zona_cat",
    "tipo_cat",
    "plataforma_cat"
]

assembler = VectorAssembler(
    inputCols=feature_cols,
    outputCol="features"
)

train_vec = assembler.transform(train_data)
test_vec = assembler.transform(test_data)

scaler = StandardScaler(
    inputCol="features",
    outputCol="scaledFeatures"
)

scaler_model = scaler.fit(train_vec)

train_data = scaler_model.transform(train_vec)
test_data = scaler_model.transform(test_vec)

# %%
from pyspark.ml.classification import DecisionTreeClassifier

dt = DecisionTreeClassifier(
    featuresCol="scaledFeatures",
    labelCol="label",
    maxDepth=5,
    seed=42
)

dt_model = dt.fit(train_data)

predictions_supervisadas = dt_model.transform(test_data)

predictions_supervisadas.select(
    "label",
    "prediction",
    "probability"
).show(10, False)
# Out:
# +-----+----------+----------------------------------------------------------------------+
# |label|prediction|probability                                                           |
# +-----+----------+----------------------------------------------------------------------+
# |0    |0.0       |[0.9936143039591315,0.005108556832694764,0.001277139208173691,0.0,0.0]|
# |0    |0.0       |[0.9936143039591315,0.005108556832694764,0.001277139208173691,0.0,0.0]|
# |0    |0.0       |[0.9936143039591315,0.005108556832694764,0.001277139208173691,0.0,0.0]|
# |0    |0.0       |[0.9936143039591315,0.005108556832694764,0.001277139208173691,0.0,0.0]|
# |0    |0.0       |[0.9936143039591315,0.005108556832694764,0.001277139208173691,0.0,0.0]|
# |0    |0.0       |[0.9936143039591315,0.005108556832694764,0.001277139208173691,0.0,0.0]|
# |0    |0.0       |[0.9936143039591315,0.005108556832694764,0.001277139208173691,0.0,0.0]|
# ...

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

evaluator = MulticlassClassificationEvaluator(
    labelCol="label",
    predictionCol="prediction",
    metricName="accuracy"
)

accuracy = evaluator.evaluate(
    predictions_supervisadas
)

print(
    f"Accuracy Árbol de Decisión: {accuracy*100:.2f}%"
)
# Out:
# Accuracy Árbol de Decisión: 97.16%

# %%
print("========== ÁRBOL ==========")

print(dt_model.toDebugString)
# Out:
# ========== ÁRBOL ==========
# DecisionTreeClassificationModel: uid=DecisionTreeClassifier_4ca63fd8b1c1, depth=5, numNodes=41, numClasses=5, numFeatures=7
#   If (feature 2 <= 0.24001234003156816)
#    If (feature 1 <= 1.5921994846989973)
#     If (feature 4 <= 1.0384648357100987)
#      If (feature 5 <= 3.1680910412241974)
#       Predict: 4.0
#      Else (feature 5 > 3.1680910412241974)
#       Predict: 1.0
#     Else (feature 4 > 1.0384648357100987)
#      If (feature 6 <= 1.1565039801624581)
#       If (feature 5 <= 1.7058951760437986)
#        Predict: 4.0
#       Else (feature 5 > 1.7058951760437986)
#        Predict: 1.0
#      Else (feature 6 > 1.1565039801624581)
#       Predict: 1.0
#    Else (feature 1 > 1.5921994846989973)
#     If (feature 5 <= 5.605084149858195)
#      If (feature 0 <= 2.4462630562989593)
#       Predict: 0.0
#      Else (feature 0 > 2.4462630562989593)
#       If (feature 5 <= 0.2436993108633998)
#        Predict: 3.0
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
from sklearn.tree import DecisionTreeClassifier as SklearnClassifier

df_pandas = df_supervisado.select(
    "precio_num",
    "puntuacion_num",
    "estrellas_num",
    "ciudad_cat",
    "label"
).toPandas()

X_muestra = df_pandas[
    [
        "precio_num",
        "puntuacion_num",
        "estrellas_num",
        "ciudad_cat"
    ]
]

y_muestra = df_pandas["label"]

sk_dt = SklearnClassifier(
    max_depth=3,
    random_state=42
)

sk_dt.fit(X_muestra, y_muestra)

plt.figure(figsize=(20,10))

plot_tree(
    sk_dt,
    feature_names=[
        "precio_num",
        "puntuacion_num",
        "estrellas_num",
        "ciudad_cat"
    ],
    class_names=[
        f"Cluster {int(c)}"
        for c in sorted(y_muestra.unique())
    ],
    filled=True,
    rounded=True
)

plt.title("Árbol de Decisión - Alojamientos")
plt.show()

# %% [markdown]
# # Algoritmo Supervisado: Random Forest (Bosques aleatorios), Support Vector Machine (Máquinas de Vector de Soporte), regresión logística multinomial

# %%
df_supervisado = df_clusters.withColumnRenamed(
    "prediction",
    "label"
)

train_data, test_data = df_supervisado.randomSplit(
    [0.7, 0.3],
    seed=42
)

assembler = VectorAssembler(
    inputCols=feature_cols,
    outputCol="features"
)

train_data = assembler.transform(train_data)
test_data = assembler.transform(test_data)

scaler = StandardScaler(
    inputCol="features",
    outputCol="scaledFeatures"
)

scaler_model = scaler.fit(train_data)

train_data = scaler_model.transform(train_data)
test_data = scaler_model.transform(test_data)

# %%
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

evaluator = MulticlassClassificationEvaluator(
    labelCol="label",
    predictionCol="prediction",
    metricName="accuracy"
)

# =====================================
# RANDOM FOREST
# =====================================

rf = RandomForestClassifier(
    featuresCol="scaledFeatures",
    labelCol="label",
    numTrees=10,
    seed=42
)

rf_model = rf.fit(train_data)

rf_predictions = rf_model.transform(test_data)

accuracy_rf = evaluator.evaluate(
    rf_predictions
)

# =====================================
# REGRESIÓN LOGÍSTICA
# =====================================

lr = LogisticRegression(
    featuresCol="scaledFeatures",
    labelCol="label",
    family="multinomial",
    maxIter=10
)

lr_model = lr.fit(train_data)

lr_predictions = lr_model.transform(test_data)

accuracy_lr = evaluator.evaluate(
    lr_predictions
)

# %%
print("==================================================")
print("  RESULTADOS DE MODELOS SUPERVISADOS")
print("==================================================")

print(f"Árbol de Decisión Accuracy: {accuracy * 100:.2f}%")

print(f"Random Forest Accuracy: {accuracy_rf * 100:.2f}%")

print(f"Regresión Logística Accuracy: {accuracy_lr * 100:.2f}%")

print("==================================================")
# Out:
# ...
#   RESULTADOS DE MODELOS SUPERVISADOS
# ...
# Árbol de Decisión Accuracy: 97.16%
# Random Forest Accuracy: 97.01%
# Regresión Logística Accuracy: 99.16%
# ...

# %%
df_supervisado.count()
# Out:
# 4408
