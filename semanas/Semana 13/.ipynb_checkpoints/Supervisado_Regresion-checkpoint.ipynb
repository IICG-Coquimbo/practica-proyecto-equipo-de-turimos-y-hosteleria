# %% [markdown]
# # Algoritmos de Regresión

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

spark = SparkSession.builder.appName("Semana12_Regresion_G5").getOrCreate()

# Cargar datos
df_clusters = spark.read.parquet("/home/jovyan/work/datos_etiquetados_alojamientos")

print(f"Datos cargados: {df_clusters.count()}")

# IMPORTANTE: Eliminar la columna 'prediction' porque ya existe
df_regresion = df_clusters.drop("prediction")

print("Columnas disponibles para regresión:")
print(df_regresion.columns)
# Out:
# Datos cargados: 4408
# Columnas disponibles para regresión:
# ['precio_num', 'puntuacion_num', 'estrellas_num', 'ciudad_cat', 'zona_cat', 'tipo_cat', 'plataforma_cat']

# %%
from pyspark.ml.feature import VectorAssembler, StandardScaler
from pyspark.ml.regression import LinearRegression
from pyspark.ml.evaluation import RegressionEvaluator

# Variables para predecir precio (NO incluir precio_num)
variables_regresion = ["estrellas_num", "puntuacion_num", "ciudad_cat", "zona_cat", "tipo_cat", "plataforma_cat"]

# Verificar que todas las variables existen
for var in variables_regresion:
    if var not in df_regresion.columns:
        print(f"ADVERTENCIA: {var} no existe en los datos")

# Vectorizar
assembler = VectorAssembler(inputCols=variables_regresion, outputCol="features_reg")
df_vector = assembler.transform(df_regresion)

# Escalar
scaler = StandardScaler(inputCol="features_reg", outputCol="scaledFeatures_reg")
scaler_model = scaler.fit(df_vector)
df_scaled = scaler_model.transform(df_vector)

# Renombrar variable objetivo
df_scaled = df_scaled.withColumnRenamed("precio_num", "label_precio")

# Dividir
train_reg, test_reg = df_scaled.randomSplit([0.7, 0.3], seed=42)

print(f"Entrenamiento: {train_reg.count()}")
print(f"Prueba: {test_reg.count()}")
# Out:
# Entrenamiento: 3088
# Prueba: 1320

# %%
# Regresion Lineal
lr_reg = LinearRegression(featuresCol="scaledFeatures_reg", labelCol="label_precio", maxIter=10)
lr_model = lr_reg.fit(train_reg)
predictions = lr_model.transform(test_reg)

# Evaluar
evaluator_r2 = RegressionEvaluator(labelCol="label_precio", metricName="r2")
evaluator_rmse = RegressionEvaluator(labelCol="label_precio", metricName="rmse")

r2 = evaluator_r2.evaluate(predictions)
rmse = evaluator_rmse.evaluate(predictions)

print("=" * 50)
print("REGRESION LINEAL - PREDICCION DE PRECIO")
print("=" * 50)
print(f"R2:  {r2 * 100:.2f}%")
print(f"RMSE: ${rmse:.2f}")
print("=" * 50)
# Out:
# ==================================================
# REGRESION LINEAL - PREDICCION DE PRECIO
# ==================================================
# R2:  9.60%
# RMSE: $181180.77
# ==================================================

# %%
# Mostrar coeficientes
print(f"Interseccion (precio base): ${lr_model.intercept:.2f}")
print("Coeficientes:")
for i, var in enumerate(variables_regresion):
    print(f"  {var}: ${lr_model.coefficients[i]:.2f}")
# Out:
# Interseccion (precio base): $201298.48
# Coeficientes:
#   estrellas_num: $39590.32
#   puntuacion_num: $-10663.50
#   ciudad_cat: $1761.00
#   zona_cat: $-10874.93
#   tipo_cat: $9108.89
#   plataforma_cat: $-52497.83

# %%
# Mostrar comparativa real vs predicho
predictions.select("label_precio", "prediction").show(10)
# Out:
# +------------+------------------+
# |label_precio|        prediction|
# +------------+------------------+
# |     24990.0| 170233.8264133164|
# |     29200.0|233884.62003228342|
# |     31969.0| 98127.89402211804|
# |     32238.0|180518.06854398685|
# |     33320.0|136182.36476366076|
# |     33527.0|175860.74093760326|
# |     34387.0| 193067.1825276614|
# |     37611.0|103967.08681500901|
# |     39115.0|171359.21003367295|
# |     39545.0|102466.57770619754|
# +------------+------------------+
# only showing top 10 rows

# %%
df_regresion = df_clusters.drop("prediction")
