# %% [markdown]
# # Algoritmos de Regresión

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Regresion_Alojamientos_Matias") \
    .getOrCreate()

ruta_datos = "/home/jovyan/work/datos_etiquetados_alojamientos"

df_clusters = spark.read.parquet(ruta_datos)

df_clusters.show(10)

print("Total registros:", df_clusters.count())
# Out:
# +----------+-----------------+-------------+----------+--------+--------+--------------+----------+
# |precio_num|   puntuacion_num|estrellas_num|ciudad_cat|zona_cat|tipo_cat|plataforma_cat|prediction|
# +----------+-----------------+-------------+----------+--------+--------+--------------+----------+
# |  181191.0|9.699999809265137|          0.0|       1.0|     3.0|     3.0|           0.0|         0|
# |   54396.0|              9.0|          0.0|       1.0|     3.0|     5.0|           0.0|         0|
# |  158911.0|8.699999809265137|          0.0|       1.0|     3.0|     3.0|           0.0|         0|
# |  288608.0|9.600000381469727|          0.0|       1.0|     3.0|     3.0|           0.0|         0|
# |   48800.0|              0.0|          0.0|       1.0|     3.0|     3.0|           0.0|         4|
# |   74205.0|              8.0|          4.0|       1.0|     3.0|     0.0|           0.0|         3|
# ...

# %%
from pyspark.ml.feature import VectorAssembler, StandardScaler

# Variables para predecir el precio
feature_cols_reg = [
    "puntuacion_num",
    "estrellas_num",
    "ciudad_cat",
    "zona_cat",
    "tipo_cat",
    "plataforma_cat"
]

# Crear vector de características
assembler_reg = VectorAssembler(
    inputCols=feature_cols_reg,
    outputCol="features_reg"
)

df_reg = assembler_reg.transform(df_clusters)

# Escalar variables
scaler_reg = StandardScaler(
    inputCol="features_reg",
    outputCol="scaledFeatures_reg"
)

scaler_model_reg = scaler_reg.fit(df_reg)

df_reg = scaler_model_reg.transform(df_reg)

# Variable objetivo (precio)
df_reg = df_reg.withColumnRenamed(
    "precio_num",
    "label_precio"
)

# Eliminar prediction del KMeans para evitar conflicto
if "prediction" in df_reg.columns:
    df_reg = df_reg.drop("prediction")

# Separar entrenamiento y prueba
train_reg, test_reg = df_reg.randomSplit(
    [0.7, 0.3],
    seed=42
)

print("Entrenamiento:", train_reg.count())
print("Prueba:", test_reg.count())
# Out:
# Entrenamiento: 3104
# Prueba: 1304

# %%
from pyspark.ml.regression import LinearRegression

lr_regresion = LinearRegression(
    featuresCol="scaledFeatures_reg",
    labelCol="label_precio",
    maxIter=10
)

lr_reg_model = lr_regresion.fit(train_reg)

predictions_regresion = lr_reg_model.transform(
    test_reg
)

print("=== PRECIO REAL VS PRECIO PREDICHO ===")

predictions_regresion.select(
    "label_precio",
    "prediction"
).show(10)
# Out:
# === PRECIO REAL VS PRECIO PREDICHO ===
# +------------+------------------+
# |label_precio|        prediction|
# +------------+------------------+
# |     19685.0|157043.94386053825|
# |     32200.0| 170159.0426813564|
# |     36686.0| 168548.8640696237|
# |     37000.0|167853.91786382027|
# |     38634.0| 167506.4431040361|
# |     38839.0|167624.13117341753|
# |     39459.0| 165703.9885269365|
# |     42000.0| 168548.8640696237|
# |     42363.0| 178393.1611388449|
# |     45502.0|103514.27236308088|
# +------------+------------------+
# only showing top 10 rows

# %%
from pyspark.ml.evaluation import RegressionEvaluator

evaluator_r2 = RegressionEvaluator(
    labelCol="label_precio",
    predictionCol="prediction",
    metricName="r2"
)

evaluator_rmse = RegressionEvaluator(
    labelCol="label_precio",
    predictionCol="prediction",
    metricName="rmse"
)

r2 = evaluator_r2.evaluate(
    predictions_regresion
)

rmse = evaluator_rmse.evaluate(
    predictions_regresion
)

print("==================================================")
print("      EVALUACIÓN DE LA REGRESIÓN")
print("==================================================")
print(f"R²: {r2*100:.2f}%")
print(f"RMSE: {rmse:.2f}")
print("==================================================")
# Out:
# ...
#       EVALUACIÓN DE LA REGRESIÓN
# ...
# R²: 9.43%
# RMSE: 182003.13
# ...

# %%
print("Intercepto:")
print(lr_reg_model.intercept)

print()

print("Coeficientes:")
print(lr_reg_model.coefficients)
# Out:
# Intercepto:
# 200939.48368049818
#
# Coeficientes:
# [-9877.390033050251,41563.51322026138,407.7857908732957,-10092.78263431555,5195.965416663455,-51333.527415377466]
