# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, regexp_extract, when, lit

# Configuración de la sesión con el conector de Mongo
spark = SparkSession.builder \
    .appName("EDA_Turismo_Camila") \
    .config("spark.mongodb.read.connection.uri", "mongodb://lucascheuque_db_user:27032005@ac-apanrvu-shard-00-00.tjvu2a3.mongodb.net:27017/proyecto_bigdata.alojamientos?authSource=admin&replicaSet=atlas-rjf6rx-shard-0&tls=true") \
    .config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.12:10.1.1") \
    .getOrCreate()

# Carga de datos crudos
df_raw = spark.read.format("mongodb").load()
df_raw.printSchema()

# %%
# Quitar registros exactamente iguales y aquellos sin nombre o precio
df_clean = df_raw.dropDuplicates(["nombre_hotel", "plataforma", "ciudad", "zona_geografica"]) \
    .filter(col("nombre_hotel").isNotNull()) \
    .filter(col("precio_noche").isNotNull())

print(f"Registros después de limpieza: {df_clean.count()}")

# %%
# Convertimos el precio a numérico y normalizamos a una sola moneda (EUR)
df_clean = df_clean.withColumn("precio_num", col("precio_noche").cast("double"))

df_clean = df_clean.withColumn("precio_eur",
    when(col("precio_noche") == "CLP", col("precio_num") / 980)
    .otherwise(col("precio_num"))
)

# %%
df_clean.select("precio_noche", "precio_num", "precio_eur").show(5)

# %%
# Resumen de variables numéricas (Precio y Puntuación)
df_clean.select("precio_noche", "puntuacion", "estrellas").describe().show()

# %%
from pyspark.sql.functions import count, isnan

df_clean.select([count(when(col(c).isNull(), c)).alias(c) for c in df_clean.columns]).show()
# Out:
# +---+-------+------+---------+----------+-------------+-----+-----------+----------+------+------------+----+----------+----------+-------------+------------+---------------+----------+----------------+---------------+----------+---------------+----------+----------+
# |_id|adultos|ciudad|estrellas|estudiante|fecha_captura|grupo|hotel_viaje|integrante|noches|nombre_hotel|pais|plataforma|precio_clp|precio_limpio|precio_noche|precio_original|puntuacion|tipo_alojamiento|tipo_habitacion|url_origen|zona_geografica|precio_num|precio_eur|
# +---+-------+------+---------+----------+-------------+-----+-----------+----------+------+------------+----+----------+----------+-------------+------------+---------------+----------+----------------+---------------+----------+---------------+----------+----------+
# ...

# %%
df_clean.withColumn("precio_por_noche", col("precio_noche")) \
    .groupBy("ciudad") \
    .avg("precio_por_noche") \
    .orderBy("avg(precio_por_noche)", ascending=False).show()
# Out:
# +--------------+---------------------+
# |        ciudad|avg(precio_por_noche)|
# +--------------+---------------------+
# |        Temuco|    361242.3253968254|
# |      Rancagua|   209334.20430107528|
# |     Coyhaique|    181404.7142857143|
# |Puerto Natales|   164638.66279069768|
# |        Calama|             152899.0|
# |       Copiapo|   134635.98958333334|
# |   Antofagasta|   133799.06486486486|
# |    Concepcion|   126762.33333333333|
# |  Vina del Mar|   125678.00543478261|
# |      Santiago|   123572.09248554913|
# |     La Serena|   123119.79514824798|
# |      Valdivia|   116113.31451612903|
# |         Talca|   115579.79411764706|
# |    Valparaiso|   111010.95433789954|
# |  Punta Arenas|   110132.93785310735|
# |  Puerto Varas|            98080.452|
# |       Chillan|    95141.58823529411|
# |  Puerto Montt|    94606.90243902439|
# |         Pucon|     90355.0824742268|
# |         Arica|     80738.7743902439|
# +--------------+---------------------+
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Convertimos una muestra a Pandas para graficar
pdf = df_clean.sample(False, 0.5).toPandas()

plt.figure(figsize=(10,6))
sns.boxplot(x='ciudad', y='precio_noche', data=pdf)
plt.title("Distribución de Precios por Ciudad (en CLP)")
plt.xticks(rotation=45)
plt.show()
