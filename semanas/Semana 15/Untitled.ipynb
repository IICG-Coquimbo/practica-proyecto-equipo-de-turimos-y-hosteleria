# %%
streamlit run /home/jovyan/work/semanas/Semana\ 15/app.py --server.port 8501
# Out:
#   Cell In[1], line 1
#     streamlit run /home/jovyan/work/semanas/Semana\ 15/app.py --server.port 8501
#                                                    ^
# SyntaxError: unexpected character after line continuation character

# %%
ls /home/jovyan/work/semanas/Semana\ 15/
# Out:
# 'app (1).py'   datos_alojamientos_dashboard.csv   Untitled.ipynb
#  app.py*       datos_veterinaria_dashboard.csv*

# %%
streamlit run /home/jovyan/work/semanas/Semana\ 15/app.py --server.port 8501
# Out:
#   Cell In[3], line 1
#     streamlit run /home/jovyan/work/semanas/Semana\ 15/app.py --server.port 8501
#                                                    ^
# SyntaxError: unexpected character after line continuation character
