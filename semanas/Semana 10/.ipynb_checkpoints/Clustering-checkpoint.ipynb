# %% [markdown]
# # Clusters: Aprendizaje No supervisado (K-Means)

# %%
import os
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, DoubleType
from pyspark.sql.functions import col  # <-- Importado al principio para evitar el error
from pymongo import MongoClient
import certifi

print("🚀 Inicializando PySpark para Modelamiento de Machine Learning...")

# 1. Creamos la sesión de Spark limpia
spark = SparkSession.builder \
    .appName("MachineLearning_Turismo_AngeloRojo") \
    .getOrCreate()

# 2. Conexión directa mediante PyMongo a tu clúster de Atlas
uri = "mongodb+srv://AngeloRojo:azul2003@cluster0.aibpfux.mongodb.net/?retryWrites=true&w=majority"

try:
    client = MongoClient(uri, tlsCAFile=certifi.where())
    db = client['proyecto_bigdata']
    collection = db['viajes_chile_limpios']
    
    documentos_raw = list(collection.find())
    
    # Limpieza rápida de tipos
    for doc in documentos_raw:
        if '_id' in doc:
            doc['_id'] = str(doc['_id'])
        if 'precio_num' in doc:
            try:
                import math
                if math.isnan(doc['precio_num']):
                    doc['precio_num'] = None
            except:
                pass

    # 3. Esquema real de tus datos de turismo
    schema = StructType([
        StructField("_id", StringType(), True),
        StructField("actividad", StringType(), True),
        StructField("ubicacion", StringType(), True),
        StructField("precio_texto", StringType(), True),
        StructField("precio_num", DoubleType(), True),
        StructField("plataforma", StringType(), True)
    ])

    # 4. Creamos el DataFrame oficial de Spark y estandarizamos columnas
    df_raw = spark.createDataFrame(documentos_raw, schema=schema)
    df_model = df_raw.withColumnRenamed("actividad", "identificador") \
                     .withColumnRenamed("precio_num", "valor") \
                     .filter(col("valor").isNotNull())
    
    print("\n✅ ¡DATOS CARGADOS CON ÉXITO EN EL NOTEBOOK DE CLUSTERING!")
    print(f"📊 Registros listos para entrenar el modelo: {df_model.count()}")
    df_model.select("identificador", "ubicacion", "valor").show(5, truncate=False)

except Exception as e:
    print(f"❌ Error durante la carga: {e}")
# Out:
# 🚀 Inicializando PySpark para Modelamiento de Machine Learning...
#
# ✅ ¡DATOS CARGADOS CON ÉXITO EN EL NOTEBOOK DE CLUSTERING!
# 📊 Registros listos para entrenar el modelo: 13
# +-------------+--------------------+--------+
# |identificador|ubicacion           |valor   |
# +-------------+--------------------+--------+
# |CLP$ 170.000 |SAN PEDRO DE ATACAMA|170000.0|
# |CLP$ 469.000 |TORRES DEL PAINE    |469000.0|
# |CLP$ 529.000 |TORRES DEL PAINE    |529000.0|
# |CLP$ 599.000 |TORRES DEL PAINE    |599000.0|
# |CLP$ 619.000 |TORRES DEL PAINE    |619000.0|
# +-------------+--------------------+--------+
# only showing top 5 rows

# %%
from pyspark.ml.feature import StringIndexer
from pyspark.sql.functions import col

print("🏷️ 1. Indexando la columna de destinos turísticos...")

# Convertimos 'ubicacion' en una columna numérica llamada 'ubicacion_cat'
indexer_destino = StringIndexer(inputCol="ubicacion", outputCol="ubicacion_cat", handleInvalid="keep")
df_categorized = indexer_destino.fit(df_model).transform(df_model)

# Nos aseguramos de que sea tipo entero para el modelo
df_final = df_categorized.withColumn("ubicacion_cat", col("ubicacion_cat").cast("int"))

print("✅ ¡Destinos transformados con éxito!")
df_final.select("identificador", "ubicacion", "ubicacion_cat", "valor").show(5, truncate=False)
# Out:
# 🏷️ 1. Indexando la columna de destinos turísticos...
# ✅ ¡Destinos transformados con éxito!
# +-------------+--------------------+-------------+--------+
# |identificador|ubicacion           |ubicacion_cat|valor   |
# +-------------+--------------------+-------------+--------+
# |CLP$ 170.000 |SAN PEDRO DE ATACAMA|1            |170000.0|
# |CLP$ 469.000 |TORRES DEL PAINE    |0            |469000.0|
# |CLP$ 529.000 |TORRES DEL PAINE    |0            |529000.0|
# |CLP$ 599.000 |TORRES DEL PAINE    |0            |599000.0|
# |CLP$ 619.000 |TORRES DEL PAINE    |0            |619000.0|
# +-------------+--------------------+-------------+--------+
# only showing top 5 rows

# %%
print("📊 Muestra de datos verificados con su categoría numérica:")

# Mostramos cómo quedó tu columna 'ubicacion_cat' mapeada para el modelo
df_final.select("identificador", "ubicacion", "ubicacion_cat", "valor").show(5, truncate=False)
# Out:
# 📊 Muestra de datos verificados con su categoría numérica:
# +-------------+--------------------+-------------+--------+
# |identificador|ubicacion           |ubicacion_cat|valor   |
# +-------------+--------------------+-------------+--------+
# |CLP$ 170.000 |SAN PEDRO DE ATACAMA|1            |170000.0|
# |CLP$ 469.000 |TORRES DEL PAINE    |0            |469000.0|
# |CLP$ 529.000 |TORRES DEL PAINE    |0            |529000.0|
# |CLP$ 599.000 |TORRES DEL PAINE    |0            |599000.0|
# |CLP$ 619.000 |TORRES DEL PAINE    |0            |619000.0|
# +-------------+--------------------+-------------+--------+
# only showing top 5 rows

# %% [markdown]
# # Quedarnos con un dataframe solo númerico

# %%
from pyspark.sql.functions import col

print("📊 2. Creando DataFrame numérico puro para el modelo...")

# Seleccionamos las columnas matemáticas necesarias
df_clustering = df_final.select(
    col("ubicacion_cat").cast("double").alias("destino_num"),
    col("valor").cast("double").alias("precio_num")
)

# Mostramos el esquema para verificar el cambio de tipos
df_clustering.printSchema()
df_clustering.show(5)
# Out:
# 📊 2. Creando DataFrame numérico puro para el modelo...
# root
#  |-- destino_num: double (nullable = true)
#  |-- precio_num: double (nullable = true)
#
# +-----------+----------+
# |destino_num|precio_num|
# +-----------+----------+
# |        1.0|  170000.0|
# |        0.0|  469000.0|
# |        0.0|  529000.0|
# |        0.0|  599000.0|
# |        0.0|  619000.0|
# +-----------+----------+
# only showing top 5 rows

# %% [markdown]
# # Paso 1: PCA, Principal Component Analysis

# %%
from pyspark.ml.feature import VectorAssembler, StandardScaler, PCA

print("⚡ 3. Ensamblando vectores de características...")
# Unimos el destino y el precio en la columna features
assembler = VectorAssembler(inputCols=["destino_num", "precio_num"], outputCol="features")
df_vector = assembler.transform(df_clustering)

print("⚖️ 4. Escalando los datos (StandardScaler)...")
# El escalamiento evita que los precios de CLP aplasten al número del destino
scaler = StandardScaler(inputCol="features", outputCol="scaledFeatures", withStd=True, withMean=True)
scaler_model = scaler.fit(df_vector)
df_scaled = scaler_model.transform(df_vector)

print("🔮 5. Aplicando PCA para reducción a 2 componentes...")
# Reducimos a 2 componentes para cumplir la pauta visual
pca = PCA(k=2, inputCol="scaledFeatures", outputCol="pcaFeatures")
pca_model = pca.fit(df_scaled)
df_pca = pca_model.transform(df_scaled)

print("✅ ¡PCA y Escalado terminados!")
# Out:
# ⚡ 3. Ensamblando vectores de características...
# ⚖️ 4. Escalando los datos (StandardScaler)...
# 🔮 5. Aplicando PCA para reducción a 2 componentes...
# ✅ ¡PCA y Escalado terminados!

# %%
import pandas as pd

print("📋 MATRIZ DE INFLUENCIA (LOADINGS) - TURISMO G5:")

# Extraemos los pesos matemáticos del PCA
loadings = pca_model.pc.toArray()

# Creamos el DataFrame de Pandas para visualizarlo de forma ordenada en Jupyter
variables = ["destino_num", "precio_num"]
pc_loadings = pd.DataFrame(loadings, columns=['PC1', 'PC2'], index=variables)

print(pc_loadings)
# Out:
# 📋 MATRIZ DE INFLUENCIA (LOADINGS) - TURISMO G5:
#                   PC1       PC2
# destino_num -0.707107  0.707107
# precio_num   0.707107  0.707107

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

print("🎨 Graficando la distribución espacial de tus datos de Turismo (PCA)...")

# 1. Extraemos las componentes y la columna numérica del destino que sí existe en df_pca
pdf_pca_raw = df_pca.select("pcaFeatures", "destino_num").toPandas()

# 2. Convertimos el vector de Spark a columnas PC1 y PC2 de Pandas
pdf_pca_raw[['PC1', 'PC2']] = pd.DataFrame(pdf_pca_raw['pcaFeatures'].apply(lambda x: x.toArray()).tolist())

# 3. Calculamos límites para centrar el gráfico
pc1_min, pc1_max = np.percentile(pdf_pca_raw['PC1'], [0, 100])
pc2_min, pc2_max = np.percentile(pdf_pca_raw['PC2'], [0, 100])

# 4. Graficamos diferenciando por el ID de destino
plt.figure(figsize=(11, 7))
sns.set_style("darkgrid")

sns.scatterplot(
    data=pdf_pca_raw, 
    x='PC1', 
    y='PC2', 
    hue='destino_num',    # Usamos el número de destino para diferenciar los colores
    s=120,                 # Puntos grandes para que se noten tus 13 registros
    alpha=0.9,
    palette="tab10"
)

# 5. Aplicamos el centrado
plt.xlim(pc1_min - 0.5, pc1_max + 0.5)
plt.ylim(pc2_min - 0.5, pc2_max + 0.5)

plt.title('Distribución Espacial de Oferta Turística (PCA - Turismo G5)', fontsize=15)
plt.xlabel('Componente Principal 1 (PC1)', fontsize=12)
plt.ylabel('Componente Principal 2 (PC2)', fontsize=12)
plt.legend(title="ID Destino", loc="best")

plt.tight_layout()
plt.show()
# Out:
# 🎨 Graficando la distribución espacial de tus datos de Turismo (PCA)...

# %% [markdown]
# # Paso 2: Método del codo

# %%
from pyspark.ml.clustering import KMeans
import matplotlib.pyplot as plt

print("📐 Calculando la inercia para encontrar el número óptimo de clusters (Método del Codo)...")

cost = []
# Probamos desde 2 hasta 6 clusters (adecuado para el tamaño de tu muestra de viajes)
for k in range(2, 7):
    kmeans = KMeans(featuresCol='scaledFeatures', k=k, seed=42)
    model = kmeans.fit(df_scaled)
    # Guardamos el costo de entrenamiento (inercia)
    cost.append(model.summary.trainingCost)

# Graficamos el codo de Jambu
plt.figure(figsize=(8, 5))
plt.plot(range(2, 7), cost, 'bx-')
plt.xlabel('Número de Clusters (k)')
plt.ylabel('Costo (Inercia)')
plt.title('Método del Codo para Oferta Turística (G5)')
plt.show()
# Out:
# 📐 Calculando la inercia para encontrar el número óptimo de clusters (Método del Codo)...

# %% [markdown]
# # Paso 3. Clustering Final (K-Means)

# %%
# Entrenamos el modelo final
k_optimo = 3
kmeans_final = KMeans(featuresCol='scaledFeatures', k=k_optimo, seed=42)
model_final = kmeans_final.fit(df_scaled)

# Asignamos los clusters generados a tus datos de turismo
df_clusters = model_final.transform(df_scaled)

print("✅ ¡K-Means entrenado! Muestra de la segmentación de tus viajes:")
# Mostramos tus columnas reales junto con la predicción (grupo asignado)
df_clusters.select("destino_num", "precio_num", "prediction").show(13)
# Out:
# ✅ ¡K-Means entrenado! Muestra de la segmentación de tus viajes:
# +-----------+----------+----------+
# |destino_num|precio_num|prediction|
# +-----------+----------+----------+
# |        1.0|  170000.0|         1|
# |        0.0|  469000.0|         0|
# |        0.0|  529000.0|         0|
# |        0.0|  599000.0|         0|
# |        0.0|  619000.0|         0|
# |        0.0|  949000.0|         0|
# |        0.0|  979000.0|         0|
# |        0.0|  579000.0|         0|
# |        0.0|  629000.0|         0|
# |        0.0|  199000.0|         2|
# |        0.0|  219000.0|         2|
# |        0.0|  229000.0|         2|
# |        0.0|  249000.0|         2|
# +-----------+----------+----------+

# %% [markdown]
# # Paso 4. Visualización de los Clusters

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

print("🎨 Generando el mapa de clusters final en el espacio PCA...")

# 1. Aplicamos el modelo final al dataframe que contiene las coordenadas del PCA
df_viz_final = model_final.transform(df_pca)

# 2. Pasamos a Pandas seleccionando las columnas numéricas reales de tu data
pdf_visual = df_viz_final.select("pcaFeatures", "prediction", "destino_num").toPandas()

# 3. Extraemos las coordenadas PC1 y PC2 de los vectores de Spark
pdf_visual[['PC1', 'PC2']] = pd.DataFrame(pdf_visual['pcaFeatures'].apply(lambda x: x.toArray()).tolist())

# 4. Calculamos límites perfectos para centrar tus 13 datos
pc1_min, pc1_max = np.percentile(pdf_visual['PC1'], [0, 100])
pc2_min, pc2_max = np.percentile(pdf_visual['PC2'], [0, 100])

# 5. Generamos el gráfico de dispersión con los grupos diferenciados por color
plt.figure(figsize=(12, 8))
sns.set_style("darkgrid")

sns.scatterplot(
    data=pdf_visual, 
    x='PC1', 
    y='PC2', 
    hue='prediction',      # El color representa el grupo que asignó la IA (0, 1 o 2)
    palette='viridis',     # Escala de colores profesional
    s=150,                 # Puntos grandes para que se vean claritos
    alpha=0.9,
    edgecolor='w',
    linewidth=1
)

# Aplicamos el zoom centrado
plt.xlim(pc1_min - 0.5, pc1_max + 0.5)
plt.ylim(pc2_min - 0.5, pc2_max + 0.5)

plt.title(f'Segmentación de Oferta Turística en Espacio PCA (k={k_optimo}) - G5', fontsize=15, pad=15)
plt.xlabel('Componente Principal 1 (PC1)', fontsize=12)
plt.ylabel('Componente Principal 2 (PC2)', fontsize=12)
plt.legend(title='Cluster Asignado', loc='best')

plt.tight_layout()
plt.show()
# Out:
# 🎨 Generando el mapa de clusters final en el espacio PCA...

# %% [markdown]
# # DBSCAN (Density-Based Spatial Clustering of Applications with Noise)

# %%
from sklearn.cluster import DBSCAN
import numpy as np

print("🛰️ Ejecutando clustering por densidad (DBSCAN)...")

# 1. Convertimos los datos del PCA a un array de Numpy usando tus columnas reales
pdf_dbscan = df_pca.select("pcaFeatures", "destino_num").toPandas()
X = np.array(pdf_dbscan['pcaFeatures'].apply(lambda x: x.toArray()).tolist())

# 2. Aplicamos DBSCAN adaptando los parámetros al tamaño de tu muestra (13 registros)
# Bajamos min_samples a 2 para que reconozca grupos pequeños en tus destinos
dbscan = DBSCAN(eps=0.5, min_samples=2)
clusters = dbscan.fit_predict(X)

# 3. Añadimos los resultados al DataFrame de Pandas
pdf_dbscan['cluster_dbscan'] = clusters

print("✅ ¡DBSCAN ejecutado con éxito!")
print(f"📊 Conteo de puntos por grupo (-1 significa ruido/atípico):")
print(pdf_dbscan['cluster_dbscan'].value_counts())
# Out:
# 🛰️ Ejecutando clustering por densidad (DBSCAN)...
# ✅ ¡DBSCAN ejecutado con éxito!
# 📊 Conteo de puntos por grupo (-1 significa ruido/atípico):
# cluster_dbscan
#  0    6
#  2    4
#  1    2
# -1    1
# Name: count, dtype: int64

# %% [markdown]
# ## Visualización de DBSCAN (Centrada y sin flechas)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

print("🎨 Graficando el mapa de densidad definitivo con DBSCAN...")

plt.figure(figsize=(11, 7))
sns.set_style("darkgrid")

# 1. Separamos las componentes PC1 y PC2 en el DataFrame de DBSCAN
pdf_dbscan[['PC1', 'PC2']] = pd.DataFrame(X, columns=['PC1', 'PC2'])

# 2. Calculamos los límites perfectos para centrar tus datos de turismo
pc1_min, pc1_max = np.percentile(pdf_dbscan['PC1'], [0, 100])
pc2_min, pc2_max = np.percentile(pdf_dbscan['PC2'], [0, 100])

# 3. Dibujamos el gráfico de dispersión usando los grupos de DBSCAN
scatter = sns.scatterplot(
    data=pdf_dbscan,
    x='PC1',
    y='PC2',
    hue='cluster_dbscan',   # El color muestra los grupos densos y el ruido (-1)
    palette='Set1',         # Paleta llamativa para identificar los grupos
    s=150,                  # Burbujas grandes para tus 13 registros
    alpha=0.9,
    edgecolor='w'
)

# Aplicamos un zoom ajustado a tu volumen de datos
plt.xlim(pc1_min - 0.5, pc1_max + 0.5)
plt.ylim(pc2_min - 0.5, pc2_max + 0.5)

plt.title('Clustering con DBSCAN (Detección de Densidad y Ruido - G5)', fontsize=15, pad=15)
plt.xlabel('Componente Principal 1 (PC1)', fontsize=12)
plt.ylabel('Componente Principal 2 (PC2)', fontsize=12)
plt.legend(title='Cluster (-1 = Ruido)', loc='best')

plt.tight_layout()
plt.show()
# Out:
# 🎨 Graficando el mapa de densidad definitivo con DBSCAN...
