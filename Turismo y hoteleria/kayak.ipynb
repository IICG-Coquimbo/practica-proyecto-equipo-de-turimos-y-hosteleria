# %%
import sys
sys.path.append("/home/jovyan/work")

from scrapers.scraper_lucas_cheuque import ejecutar_extraccion
from pymongo import MongoClient
import certifi

# ========== CONEXIÓN A MONGODB ATLAS ==========
URI = "mongodb+srv://lucascheuque_db_user:27032005@cluster0.tjvu2a3.mongodb.net/?retryWrites=true&w=majority"

client = MongoClient(URI, tlsCAFile=certifi.where(), serverSelectionTimeoutMS=5000)
db = client['proyecto_bigdata']
coleccion = db['kayak_chile']  # Tu colección en Atlas

print("✅ Conectado a MongoDB Atlas")

# ========== EJECUTAR SCRAPER ==========
print("\n🚀 Iniciando scraping de Kayak.cl...")
datos = ejecutar_extraccion()

# ========== GUARDAR EN ATLAS ==========
guardados = 0
for doc in datos:
    coleccion.update_one(
        {
            'nombre_hotel': doc['nombre_hotel'],
            'ciudad': doc['ciudad'],
            'plataforma': 'Kayak.cl'
        },
        {'$set': doc},
        upsert=True
    )
    guardados += 1

print(f"\n✅ {guardados} registros guardados en MongoDB Atlas")
print(f"📊 Total en colección 'kayak_chile': {coleccion.count_documents({})}")
print(f"📊 Total en proyecto_bigdata: {sum(db[col].count_documents({}) for col in db.list_collection_names())}")
# Out:
# ✅ Conectado a MongoDB Atlas
#
# 🚀 Iniciando scraping de Kayak.cl...
#   Arica: 26 hoteles extraídos
#   Iquique: 26 hoteles extraídos
#   Calama: 21 hoteles extraídos
#   Antofagasta: 26 hoteles extraídos
#   Copiapo: 25 hoteles extraídos
#   La Serena: 25 hoteles extraídos
#   Valparaiso: 25 hoteles extraídos
#   Vina del Mar: 25 hoteles extraídos
#   Santiago: 27 hoteles extraídos
#   Rancagua: 25 hoteles extraídos
#   Talca: 25 hoteles extraídos
#   Chillan: 25 hoteles extraídos
#   Concepcion: 26 hoteles extraídos
#   Temuco: 26 hoteles extraídos
#   Valdivia: 25 hoteles extraídos
#   Puerto Varas: 25 hoteles extraídos
#   Puerto Montt: 26 hoteles extraídos
#   Coyhaique: 25 hoteles extraídos
#   Puerto Natales: 26 hoteles extraídos
#   Punta Arenas: 26 hoteles extraídos
#
# ✅ 506 registros guardados en MongoDB Atlas
# 📊 Total en colección 'kayak_chile': 506
# 📊 Total en proyecto_bigdata: 5209
