# %%
from pymongo import MongoClient
import certifi
import time

# Tu conexión probada de la Semana 4
uri = "mongodb+srv://AngeloRojo:<password>@cluster0.aibpfux.mongodb.net/?appName=Cluster0"

try:
    client = MongoClient(uri, tlsCAFile=certifi.where())
    client.admin.command('ping')
    print("✅ SEMANA 4: ¡CONEXIÓN EXITOSA! Tu historial está respaldado.")
except Exception as e:
    print(f"❌ Error: {e}")
# Out:
# ❌ Error: bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}

# %%
from pymongo import MongoClient
import certifi
import time

# Tu conexión probada de la Semana 4
uri = "mongodb+srv://AngeloRojo:azul2003@cluster0.aibpfux.mongodb.net/?appName=Cluster0"

try:
    client = MongoClient(uri, tlsCAFile=certifi.where())
    client.admin.command('ping')
    print("✅ SEMANA 4: ¡CONEXIÓN EXITOSA! Tu historial está respaldado.")
except Exception as e:
    print(f"❌ Error: {e}")
# Out:
# ✅ SEMANA 4: ¡CONEXIÓN EXITOSA! Tu historial está respaldado.
